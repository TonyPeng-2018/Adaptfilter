# %%
# problem the encoder decoder significantly change the distribution of the client output
# also many zero exist in the output

import torch

# load the weights of the decoder
decoder = torch.load('Weights/imagenet/middle/resnet_imagenet_middle_16.pth')
print(decoder.keys())
# Out:
# odict_keys(['in_layer.0.weight', 'in_layer.1.weight', 'in_layer.1.bias', 'in_layer.1.running_mean', 'in_layer.1.running_var', 'in_layer.1.num_batches_tracked', 'out_layer.0.weight', 'out_layer.1.weight', 'out_layer.1.bias', 'out_layer.1.running_mean', 'out_layer.1.running_var', 'out_layer.1.num_batches_tracked'])

# %%
print(decoder['out_layer.0.weight'].size())
print(decoder['out_layer.0.weight'])
print(decoder['out_layer.1.bias'])
# Out:
# torch.Size([64, 16, 3, 3])
# tensor([[[[-0.1306, -0.3230, -0.0448],
#           [ 0.1782, -0.0539,  0.0672],
#           [-0.0346,  0.0399,  0.0909]],
#
#          [[-0.1623, -0.0755,  0.0826],
#           [-0.0005, -0.0792,  0.1730],
#           [ 0.0123, -0.0141,  0.0342]],
#
#          [[ 0.0779,  0.1664,  0.0832],
#           [ 0.0531,  0.1493, -0.0377],
#           [ 0.0197,  0.0346,  0.0212]],
#
#          ...,
#
#          [[-0.0378,  0.0612, -0.0769],
#           [-0.0189, -0.0264, -0.0811],
#           [-0.0087,  0.0500, -0.0681]],
#
#          [[ 0.0265, -0.0757,  0.1848],
#           [-0.0634, -0.0408,  0.1161],
#           [-0.0322, -0.0762, -0.0792]],
#
#          [[ 0.0863, -0.0074, -0.0055],
#           [ 0.0551, -0.0721, -0.1626],
#           [-0.0317, -0.1830, -0.1034]]],
#
#
#         [[[ 0.0217, -0.0885, -0.0846],
#           [ 0.1491, -0.1319, -0.0488],
#           [ 0.0118,  0.0044, -0.1003]],
#
#          [[-0.0691, -0.0969, -0.1228],
# ...
