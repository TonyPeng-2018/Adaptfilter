# %%
# test torch stat
import torchstat
import torch
from Models import mobilenetv2

model = mobilenetv2.MobileNetV2()
model.eval()
stat = torchstat.stat(model, (3, 224, 224))
print(stat)
# Out:
# /home/tonypeng/anaconda3/envs/iot/lib/python3.12/site-packages/torchstat/model_hook.py:65: FutureWarning: In the future `np.long` will be defined as the corresponding NumPy scalar.
#   np.array([parameter_quantity], dtype=np.long))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 8
#       6 model = mobilenetv2.MobileNetV2()
#       7 model.eval()
# ----> 8 stat = torchstat.stat(model, (3, 224, 224))
#       9 print(stat)
#
# File ~/anaconda3/envs/iot/lib/python3.12/site-packages/torchstat/statistics.py:71, in stat(model, input_size, query_granularity)
#      69 def stat(model, input_size, query_granularity=1):
#      70     ms = ModelStat(model, input_size, query_granularity)
# ---> 71     ms.show_report()
#
# File ~/anaconda3/envs/iot/lib/python3.12/site-packages/torchstat/statistics.py:64, in ModelStat.show_report(self)
#      63 def show_report(self):
# ...
