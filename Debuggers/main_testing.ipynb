# %%
# this is the total pipeline for the project
# This file is for trainning
# Run this on the server, or as we called offline. 

# with gated, no generator
from Dataloaders.dataloader_cifar10 import Dataloader_cifar10
import argparse
import torch
import os
import sys
import numpy as np
import time
from Models import mobilenetv2
from Utils import utils
from Models import gatedmodel
from Models import generator

def main(args):
    # initial using mobilenetV2, and cifar10
    # we need a if statement here to decide which model and dataset to use
    # random_seed = 2024

    # for training, it is for training the generator 
    # recall the graph, when we cut more features, the performance should be worse.
    
    # get the training loader, freeze the model. Where is the partitioning point? 

    # 1. get the train, test and val datasets, and labels.
    if args.dataset == 'cifar10':
        # return train, test, val, labels, these are all dataloaders
        _, test, classes = Dataloader_cifar10(train_batch=128, test_batch=100, seed=2024)
    elif args.dataset == 'cifar100':
        pass
    
    # 2. transfer the dataset to fit the model, for the training, client and server model are all on the server
    if args.model == 'mobilenetV2':
        client_model, server_model = mobilenetv2.stupid_model_splitter(weight_path='./Weights/cifar-10/MobileNetV2.pth')
    elif args.model == 'resnet':
        pass

    # 3. get the gating, gating here decides how many channels are transferred to the server
    # simple version: a binary tree, complex version: model
    # get a ranker to rank the channels, and get the top k channels
    ranker = utils.ranker_entropy # input: embs, percentage, output: s_emb, s_ind

    # 4. get the gated model, we have 3 models here
    gated_rates = [0.25, 0.5, 0.75]
    channel2ind = {8:0, 16:1, 24:2, 32:3}
    input_channel = 32
    gateds = []
    for i in range(3):
        gateds.append(gatedmodel.GatedRegression(
            input_size=int(input_channel*gated_rates[i]),
            weight=32,
            height=32,
            output_size=10)) #  input_size, weight, height, output_size=10

    # 5. get the generator
    generators = []
    for i in range(3):
        generators.append(generator.Generator(
            inputsize=int(input_channel*gated_rates[i]), 
            hiddensize=32, 
            outputsize=32)) # inputsize, hiddensize, outputsize
        
    # 6. get the server 
    # server_model = some_model_function()
    # server model is got above

    # pipline data -> dataloader -> client_model -> gating -> reducer -> generator -> server_model
    
    # cuda may not have enough space for putting all the models
    # client_model = client_model.cuda()
    # server_model = server_model.cuda()
    # for i in range(3):
    #     gateds[i] = gateds[i].cuda()
    #     generators[i] = generators[i].cuda()

    # set them to eval
    client_model.eval()
    server_model.eval()
    for i in range(3):
        gateds[i].eval()
        generators[i].eval()

    globbal_threshold = 0.8 # set a small value first

    # load the test data set the test
    with torch.no_grad():
        correct = 0
        total = 0
        client_model = client_model.cuda()
        server_model = server_model.cuda()
        for data in test:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            # first, run the client model on the iot
            out = client_model(images)
            # second, run the ranker
            exit_flag = args.gated
            counter = 0
            while exit_flag:
                # get the emb and ind from the ranker
                out = out.cpu()
                s_emb, s_ind = ranker(out, gated_rates[counter])
                s_emb = s_emb.cuda()
                # give it to the gated model
                cur_gated = gateds[counter]
                # load the weights
                cur_gated.load_state_dict(torch.load('./Weights/cifar-10/GatedRegression_'+str(counter)+'.pth'))
                cur_gated = cur_gated.cuda()
                g_emb = cur_gated(s_emb) # b, n
                # get the argmax
                g_conf = torch.max(g_emb, dim=1).values # b
                # use the sigmoid to get the confidence
                g_conf = torch.nn.functional.sigmoid(g_conf) # b
                # if in a batch, get the average
                g_conf = torch.mean(g_conf)
                # print('The confidence is: ', g_conf.item())
                if g_conf > globbal_threshold:
                    exit_flag = not exit_flag
                else:
                    counter += 1

            # check the exit flag and send
            if exit_flag != args.gated:
                out = s_emb

            # a sender here, but on server, we don't have it.
            
            # a receiver here, but on server, we don't have it.
            # get the generator
            rec_size = out.size(1)
            if exit_flag != args.gated:
                rec_ind = s_ind
            rec_size2ind = channel2ind[rec_size]
            # if we don't get all features, we need to use the generator

            if args.generator:
                if rec_size2ind != 3:
                    cur_gen = generators[rec_size2ind]
                    # load weights
                    cur_gen.load_state_dict(torch.load('./Weights/cifar-10/generator_'+str(rec_size2ind)+'.pth'))
                    cur_gen = cur_gen.cuda()
                    out = cur_gen(out)

            # skip the generator, create a tensor with all zeros
            else:
                if exit_flag != args.gated:
                    n_out = torch.zeros(out.size(0), 32, 32, 32).cuda()
                    n_out[:, rec_ind, :, :] = out
                    out = n_out

            # run the server model
            out = server_model(out)
            _, predicted = torch.max(out.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))

# if __name__ == '__main__':
#     print('enter')
#     parser = argparse.ArgumentParser()
#     # we need the name of model, the name of dataset
#     parser.add_argument('--dataset', type=str, default='cifar10', help='name of dataset')
#     # parser.add_argument('--iot_model', type=str, default='mobilenetV2', help='name of the model on the iot')
#     parser.add_argument('--reducer', type=str, default='entrophy', help='name of the reducer')
#     parser.add_argument('--client', type=str, default='LTE', help='name of the network condition on the client side')
#     parser.add_argument('--server', type=str, default='LTE', help='name of the network condition on the server side')
#     parser.add_argument('--generator', type=str, default='None', help='name of the generator')
#     # parser.add_argument('--server_model', type=str, default='mobilenetV2', help='name of the model on the server, should be the same as it on the iot')
#     parser.add_argument('--device', type=str, default='home', help='run on which device, home, tintin, rpi, pico, jetson?')
#     parser.add_argument('--model', type=str, default='mobilenetV2', help='name of the model')
#     args = parser.parse_args()
#     main(args)

class custom_args:
    def __init__(self):
        self.dataset = 'cifar10'
        self.model = 'mobilenetV2'
        self.gated = False
        self.ranker = 'entropy'
        self.generator = False

    def __str__(self):
        return 'dataset: '+self.dataset+', model: '+self.model+', gated: '+str(self.gated)+', ranker: '+self.ranker+', generator: '+str(self.generator)

args = custom_args()
print(args)
main(args)
# Out:
# dataset: cifar10, model: mobilenetV2, gated: False, ranker: entropy, generator: False
# Files already downloaded and verified
# Files already downloaded and verified
# Accuracy of the network on the 10000 test images: 92 %

# %%
# this is the total pipeline for the project
# This file is for trainning
# Run this on the server, or as we called offline. 

# with gated, no generator
from Dataloaders.dataloader_cifar10 import Dataloader_cifar10
import argparse
import torch
import os
import sys
import numpy as np
import time
from Models import mobilenetv2
from Utils import utils
from Models import gatedmodel
from Models import generator

def main(args):
    # initial using mobilenetV2, and cifar10
    # we need a if statement here to decide which model and dataset to use
    # random_seed = 2024

    # for training, it is for training the generator 
    # recall the graph, when we cut more features, the performance should be worse.
    
    # get the training loader, freeze the model. Where is the partitioning point? 

    # 1. get the train, test and val datasets, and labels.
    if args.dataset == 'cifar10':
        # return train, test, val, labels, these are all dataloaders
        _, test, classes = Dataloader_cifar10(train_batch=128, test_batch=100, seed=2024)
    elif args.dataset == 'cifar100':
        pass
    
    # 2. transfer the dataset to fit the model, for the training, client and server model are all on the server
    if args.model == 'mobilenetV2':
        client_model, server_model = mobilenetv2.stupid_model_splitter(weight_path='./Weights/cifar-10/MobileNetV2.pth')
    elif args.model == 'resnet':
        pass

    # 3. get the gating, gating here decides how many channels are transferred to the server
    # simple version: a binary tree, complex version: model
    # get a ranker to rank the channels, and get the top k channels
    ranker = utils.ranker_entropy # input: embs, percentage, output: s_emb, s_ind

    # 4. get the gated model, we have 3 models here
    gated_rates = [0.25, 0.5, 0.75]
    channel2ind = {8:0, 16:1, 24:2, 32:3}
    input_channel = 32
    gateds = []
    for i in range(3):
        gateds.append(gatedmodel.GatedRegression(
            input_size=int(input_channel*gated_rates[i]),
            weight=32,
            height=32,
            output_size=10)) #  input_size, weight, height, output_size=10

    # 5. get the generator
    generators = []
    for i in range(3):
        generators.append(generator.Generator(
            inputsize=int(input_channel*gated_rates[i]), 
            hiddensize=32, 
            outputsize=32)) # inputsize, hiddensize, outputsize
        
    # 6. get the server 
    # server_model = some_model_function()
    # server model is got above

    # pipline data -> dataloader -> client_model -> gating -> reducer -> generator -> server_model
    
    # cuda may not have enough space for putting all the models
    # client_model = client_model.cuda()
    # server_model = server_model.cuda()
    # for i in range(3):
    #     gateds[i] = gateds[i].cuda()
    #     generators[i] = generators[i].cuda()

    # set them to eval
    client_model.eval()
    server_model.eval()
    for i in range(3):
        gateds[i].eval()
        generators[i].eval()

    globbal_threshold = 0.8 # set a small value first

    # load the test data set the test
    with torch.no_grad():
        correct = 0
        total = 0
        client_model = client_model.cuda()
        server_model = server_model.cuda()
        for data in test:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            # first, run the client model on the iot
            out = client_model(images)
            # second, run the ranker
            exit_flag = args.gated
            counter = 0
            while exit_flag:
                # get the emb and ind from the ranker
                out = out.cpu()
                s_emb, s_ind = ranker(out, gated_rates[counter])
                s_emb = s_emb.cuda()
                # give it to the gated model
                cur_gated = gateds[counter]
                # load the weights
                cur_gated.load_state_dict(torch.load('./Weights/cifar-10/GatedRegression_'+str(counter)+'.pth'))
                cur_gated = cur_gated.cuda()
                g_emb = cur_gated(s_emb) # b, n
                # get the argmax
                g_conf = torch.max(g_emb, dim=1).values # b
                # use the sigmoid to get the confidence
                g_conf = torch.nn.functional.sigmoid(g_conf) # b
                # if in a batch, get the average
                g_conf = torch.mean(g_conf)
                # print('The confidence is: ', g_conf.item())
                if g_conf > globbal_threshold:
                    exit_flag = not exit_flag
                else:
                    counter += 1

            # check the exit flag and send
            if exit_flag != args.gated:
                print('The choosen gate is: ', counter, 'The confidence is: ', g_conf.item(), 'The size of channel is: ', s_emb.size(1))
                out = s_emb

            # a sender here, but on server, we don't have it.
            
            # a receiver here, but on server, we don't have it.
            # get the generator
            rec_size = out.size(1)
            if exit_flag != args.gated:
                rec_ind = s_ind
            rec_size2ind = channel2ind[rec_size]
            # if we don't get all features, we need to use the generator

            if args.generator:
                if rec_size2ind != 3:
                    cur_gen = generators[rec_size2ind]
                    # load weights
                    cur_gen.load_state_dict(torch.load('./Weights/cifar-10/generator_'+str(rec_size2ind)+'.pth'))
                    cur_gen = cur_gen.cuda()
                    out = cur_gen(out)

            # skip the generator, create a tensor with all zeros
            else:
                if exit_flag != args.gated:
                    n_out = torch.zeros(out.size(0), 32, 32, 32).cuda()
                    n_out[:, rec_ind, :, :] = out
                    out = n_out

            # run the server model
            out = server_model(out)
            _, predicted = torch.max(out.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))

# if __name__ == '__main__':
#     print('enter')
#     parser = argparse.ArgumentParser()
#     # we need the name of model, the name of dataset
#     parser.add_argument('--dataset', type=str, default='cifar10', help='name of dataset')
#     # parser.add_argument('--iot_model', type=str, default='mobilenetV2', help='name of the model on the iot')
#     parser.add_argument('--reducer', type=str, default='entrophy', help='name of the reducer')
#     parser.add_argument('--client', type=str, default='LTE', help='name of the network condition on the client side')
#     parser.add_argument('--server', type=str, default='LTE', help='name of the network condition on the server side')
#     parser.add_argument('--generator', type=str, default='None', help='name of the generator')
#     # parser.add_argument('--server_model', type=str, default='mobilenetV2', help='name of the model on the server, should be the same as it on the iot')
#     parser.add_argument('--device', type=str, default='home', help='run on which device, home, tintin, rpi, pico, jetson?')
#     parser.add_argument('--model', type=str, default='mobilenetV2', help='name of the model')
#     args = parser.parse_args()
#     main(args)

class custom_args:
    def __init__(self):
        self.dataset = 'cifar10'
        self.model = 'mobilenetV2'
        self.gated = True
        self.ranker = 'entropy'
        self.generator = False

    def __str__(self):
        return 'dataset: '+self.dataset+', model: '+self.model+', gated: '+str(self.gated)+', ranker: '+self.ranker+', generator: '+str(self.generator)

args = custom_args()
print(args)
main(args)
# Out:
# dataset: cifar10, model: mobilenetV2, gated: True, ranker: entropy, generator: False
# Files already downloaded and verified
# Files already downloaded and verified
# The choosen gate is:  2 The confidence is:  0.9185076951980591 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9314259886741638 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9438068866729736 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9382859468460083 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9323540329933167 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9263461232185364 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9268186092376709 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9276459813117981 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9329802989959717 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9402517676353455 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9618804454803467 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9211828112602234 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9123361110687256 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9129980802536011 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9219720363616943 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9266440868377686 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9190303087234497 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.932267963886261 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.943831741809845 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9344115853309631 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9358924627304077 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9383499026298523 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9236720204353333 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9258277416229248 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9164706468582153 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9080617427825928 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9345862865447998 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9448888897895813 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9453720450401306 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9520607590675354 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9344547986984253 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9186301827430725 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9284870624542236 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9413834810256958 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9259880781173706 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9135465621948242 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9348283410072327 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9231532216072083 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9291273355484009 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9526845216751099 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.930692732334137 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9366456270217896 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9198127388954163 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9232281446456909 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9223382472991943 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9331575036048889 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9519314169883728 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9326690435409546 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9341019988059998 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9455041885375977 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9291502237319946 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9179186820983887 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9340229630470276 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9371572136878967 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9355812072753906 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9605907201766968 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9290497899055481 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9459705948829651 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9388954043388367 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9293802976608276 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9468585252761841 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9257830381393433 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9560696482658386 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9250034689903259 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9003369212150574 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9295251965522766 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9292259216308594 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9269997477531433 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9284196496009827 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9358343482017517 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9032501578330994 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9636666774749756 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9417507648468018 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9462674260139465 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9380038380622864 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9412736296653748 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9250637888908386 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9365777373313904 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9076579213142395 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9344343543052673 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9290959239006042 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.909418523311615 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.924294650554657 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9401056170463562 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9375143051147461 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9316039681434631 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9317284822463989 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9378608465194702 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9220454692840576 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9274899959564209 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9162232875823975 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.934110164642334 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9350112676620483 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9638673067092896 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9443368315696716 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9648966193199158 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.929606020450592 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9387801289558411 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9535372853279114 The size of channel is:  24
# The choosen gate is:  2 The confidence is:  0.9421201944351196 The size of channel is:  24
# Accuracy of the network on the 10000 test images: 92 %

# %%
# this is the total pipeline for the project
# This file is for trainning
# Run this on the server, or as we called offline. 

# with gated, no generator
from Dataloaders.dataloader_cifar10 import Dataloader_cifar10
import argparse
import torch
import os
import sys
import numpy as np
import time
from Models import mobilenetv2
from Utils import utils
from Models import gatedmodel
from Models import generator

def main(args):
    # initial using mobilenetV2, and cifar10
    # we need a if statement here to decide which model and dataset to use
    # random_seed = 2024

    # for training, it is for training the generator 
    # recall the graph, when we cut more features, the performance should be worse.
    
    # get the training loader, freeze the model. Where is the partitioning point? 

    # 1. get the train, test and val datasets, and labels.
    if args.dataset == 'cifar10':
        # return train, test, val, labels, these are all dataloaders
        _, test, classes = Dataloader_cifar10(train_batch=128, test_batch=100, seed=2024)
    elif args.dataset == 'cifar100':
        pass
    
    # 2. transfer the dataset to fit the model, for the training, client and server model are all on the server
    if args.model == 'mobilenetV2':
        client_model, server_model = mobilenetv2.stupid_model_splitter(weight_path='./Weights/cifar-10/MobileNetV2.pth')
    elif args.model == 'resnet':
        pass

    # 3. get the gating, gating here decides how many channels are transferred to the server
    # simple version: a binary tree, complex version: model
    # get a ranker to rank the channels, and get the top k channels
    ranker = utils.ranker_entropy # input: embs, percentage, output: s_emb, s_ind

    # 4. get the gated model, we have 3 models here
    gated_rates = [0.25, 0.5, 0.75]
    channel2ind = {8:0, 16:1, 24:2, 32:3}
    input_channel = 32
    gateds = []
    for i in range(3):
        gateds.append(gatedmodel.GatedRegression(
            input_size=int(input_channel*gated_rates[i]),
            weight=32,
            height=32,
            output_size=10)) #  input_size, weight, height, output_size=10

    # 5. get the generator
    generators = []
    for i in range(3):
        generators.append(generator.Generator(
            inputsize=int(input_channel*gated_rates[i]), 
            hiddensize=32, 
            outputsize=32)) # inputsize, hiddensize, outputsize
        
    # 6. get the server 
    # server_model = some_model_function()
    # server model is got above

    # pipline data -> dataloader -> client_model -> gating -> reducer -> generator -> server_model
    
    # cuda may not have enough space for putting all the models
    # client_model = client_model.cuda()
    # server_model = server_model.cuda()
    # for i in range(3):
    #     gateds[i] = gateds[i].cuda()
    #     generators[i] = generators[i].cuda()

    # set them to eval
    client_model.eval()
    server_model.eval()
    for i in range(3):
        gateds[i].eval()
        generators[i].eval()

    globbal_threshold = 0.8 # set a small value first

    # load the test data set the test
    with torch.no_grad():
        correct = 0
        total = 0
        client_model = client_model.cuda()
        server_model = server_model.cuda()
        for data in test:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            # first, run the client model on the iot
            out = client_model(images)
            # second, run the ranker
            exit_flag = args.gated
            counter = 0
            while exit_flag:
                # get the emb and ind from the ranker
                out = out.cpu()
                s_emb, s_ind = ranker(out, gated_rates[counter])
                s_emb = s_emb.cuda()
                # give it to the gated model
                cur_gated = gateds[counter]
                # load the weights
                cur_gated.load_state_dict(torch.load('./Weights/cifar-10/GatedRegression_'+str(counter)+'.pth'))
                cur_gated = cur_gated.cuda()
                g_emb = cur_gated(s_emb) # b, n
                # get the argmax
                g_conf = torch.max(g_emb, dim=1).values # b
                # use the sigmoid to get the confidence
                g_conf = torch.nn.functional.sigmoid(g_conf) # b
                # if in a batch, get the average
                g_conf = torch.mean(g_conf)
                # print('The confidence is: ', g_conf.item())
                if g_conf > globbal_threshold:
                    exit_flag = not exit_flag
                else:
                    counter += 1

            # check the exit flag and send
            if exit_flag != args.gated:
                print('The choosen gate is: ', counter)
                out = s_emb

            # a sender here, but on server, we don't have it.
            
            # a receiver here, but on server, we don't have it.
            # get the generator
            rec_size = out.size(1)
            if exit_flag != args.gated:
                rec_ind = s_ind
            rec_size2ind = channel2ind[rec_size]
            # if we don't get all features, we need to use the generator
            if args.generator:
                if rec_size2ind != 3:
                    cur_gen = generators[rec_size2ind]
                    # load weights
                    cur_gen.load_state_dict(torch.load('./Weights/cifar-10/generator_'+str(rec_size2ind)+'.pth'))
                    cur_gen = cur_gen.cuda()
                    out = cur_gen(out)

            # skip the generator, create a tensor with all zeros
            else:
                if exit_flag != args.gated:
                    n_out = torch.zeros(out.size(0), 32, 32, 32).cuda()
                    n_out[:, rec_ind, :, :] = out
                    out = n_out

            # run the server model
            out = server_model(out)
            _, predicted = torch.max(out.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))

# if __name__ == '__main__':
#     print('enter')
#     parser = argparse.ArgumentParser()
#     # we need the name of model, the name of dataset
#     parser.add_argument('--dataset', type=str, default='cifar10', help='name of dataset')
#     # parser.add_argument('--iot_model', type=str, default='mobilenetV2', help='name of the model on the iot')
#     parser.add_argument('--reducer', type=str, default='entrophy', help='name of the reducer')
#     parser.add_argument('--client', type=str, default='LTE', help='name of the network condition on the client side')
#     parser.add_argument('--server', type=str, default='LTE', help='name of the network condition on the server side')
#     parser.add_argument('--generator', type=str, default='None', help='name of the generator')
#     # parser.add_argument('--server_model', type=str, default='mobilenetV2', help='name of the model on the server, should be the same as it on the iot')
#     parser.add_argument('--device', type=str, default='home', help='run on which device, home, tintin, rpi, pico, jetson?')
#     parser.add_argument('--model', type=str, default='mobilenetV2', help='name of the model')
#     args = parser.parse_args()
#     main(args)

class custom_args:
    def __init__(self):
        self.dataset = 'cifar10'
        self.model = 'mobilenetV2'
        self.gated = True
        self.ranker = 'entropy'
        self.generator = True

    def __str__(self):
        return 'dataset: '+self.dataset+', model: '+self.model+', gated: '+str(self.gated)+', ranker: '+self.ranker+', generator: '+str(self.generator)

args = custom_args()
print(args)
main(args)
# Out:
# dataset: cifar10, model: mobilenetV2, gated: True, ranker: entropy, generator: True
# Files already downloaded and verified
# Files already downloaded and verified
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# The choosen gate is:  2
# Accuracy of the network on the 10000 test images: 13 %

# %%
# this is the total pipeline for the project
# This file is for trainning
# Run this on the server, or as we called offline. 

# with gated, no generator
from Dataloaders.dataloader_cifar10 import Dataloader_cifar10
import argparse
import torch
import os
import sys
import numpy as np
import time
from Models import mobilenetv2
from Utils import utils
from Models import gatedmodel
from Models import generator

def main(args):
    # initial using mobilenetV2, and cifar10
    # we need a if statement here to decide which model and dataset to use
    # random_seed = 2024

    # for training, it is for training the generator 
    # recall the graph, when we cut more features, the performance should be worse.
    
    # get the training loader, freeze the model. Where is the partitioning point? 

    # 1. get the train, test and val datasets, and labels.
    if args.dataset == 'cifar10':
        # return train, test, val, labels, these are all dataloaders
        _, test, classes = Dataloader_cifar10(train_batch=128, test_batch=100, seed=2024)
    elif args.dataset == 'cifar100':
        pass
    
    # 2. transfer the dataset to fit the model, for the training, client and server model are all on the server
    if args.model == 'mobilenetV2':
        client_model, server_model = mobilenetv2.stupid_model_splitter(weight_path='./Weights/cifar-10/MobileNetV2.pth')
    elif args.model == 'resnet':
        pass

    # 3. get the gating, gating here decides how many channels are transferred to the server
    # simple version: a binary tree, complex version: model
    # get a ranker to rank the channels, and get the top k channels
    ranker = utils.ranker_entropy # input: embs, percentage, output: s_emb, s_ind

    # 4. get the gated model, we have 3 models here
    gated_rates = [0.25, 0.5, 0.75]
    channel2ind = {8:0, 16:1, 24:2, 32:3}
    input_channel = 32
    gateds = []
    for i in range(3):
        gateds.append(gatedmodel.GatedRegression(
            input_size=int(input_channel*gated_rates[i]),
            weight=32,
            height=32,
            output_size=10)) #  input_size, weight, height, output_size=10

    # 5. get the generator
    generators = []
    for i in range(3):
        generators.append(generator.Generator(
            inputsize=int(input_channel*gated_rates[i]), 
            hiddensize=32, 
            outputsize=32)) # inputsize, hiddensize, outputsize
        
    # 6. get the server 
    # server_model = some_model_function()
    # server model is got above

    # pipline data -> dataloader -> client_model -> gating -> reducer -> generator -> server_model
    
    # cuda may not have enough space for putting all the models
    # client_model = client_model.cuda()
    # server_model = server_model.cuda()
    # for i in range(3):
    #     gateds[i] = gateds[i].cuda()
    #     generators[i] = generators[i].cuda()

    # set them to eval
    client_model.eval()
    server_model.eval()
    for i in range(3):
        gateds[i].eval()
        generators[i].eval()

    globbal_threshold = 0.8 # set a small value first

    # load the test data set the test
    with torch.no_grad():
        correct = 0
        total = 0
        client_model = client_model.cuda()
        server_model = server_model.cuda()
        for data in test:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            # first, run the client model on the iot
            out = client_model(images)
            # second, run the ranker
            exit_flag = args.gated
            counter = 0
            while exit_flag:
                # get the emb and ind from the ranker
                out = out.cpu()
                s_emb, s_ind = ranker(out, gated_rates[counter])
                s_emb = s_emb.cuda()
                # give it to the gated model
                cur_gated = gateds[counter]
                # load the weights
                cur_gated.load_state_dict(torch.load('./Weights/cifar-10/GatedRegression_'+str(counter)+'.pth'))
                cur_gated = cur_gated.cuda()
                g_emb = cur_gated(s_emb) # b, n
                # get the argmax
                g_conf = torch.max(g_emb, dim=1).values # b
                # use the sigmoid to get the confidence
                g_conf = torch.nn.functional.sigmoid(g_conf) # b
                # if in a batch, get the average
                g_conf = torch.mean(g_conf)
                # print('The confidence is: ', g_conf.item())
                if counter == 1:
                    exit_flag = not exit_flag
                    break
                if g_conf > globbal_threshold:
                    exit_flag = not exit_flag
                else:
                    counter += 1

            # check the exit flag and send
            if exit_flag != args.gated:
                print('The choosen gate is: ', counter, 'The confidence is: ', g_conf.item(), 'The size of channel is: ', s_emb.size(1))
                out = s_emb

            # a sender here, but on server, we don't have it.
            
            # a receiver here, but on server, we don't have it.
            # get the generator
            rec_size = out.size(1)
            if exit_flag != args.gated:
                rec_ind = s_ind
            rec_size2ind = channel2ind[rec_size]
            # if we don't get all features, we need to use the generator

            if args.generator:
                if rec_size2ind != 3:
                    cur_gen = generators[rec_size2ind]
                    # load weights
                    cur_gen.load_state_dict(torch.load('./Weights/cifar-10/generator_'+str(rec_size2ind)+'.pth'))
                    cur_gen = cur_gen.cuda()
                    out = cur_gen(out)

            # skip the generator, create a tensor with all zeros
            else:
                if exit_flag != args.gated:
                    n_out = torch.zeros(out.size(0), 32, 32, 32).cuda()
                    n_out[:, rec_ind, :, :] = out
                    out = n_out

            # run the server model
            out = server_model(out)
            _, predicted = torch.max(out.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))

# if __name__ == '__main__':
#     print('enter')
#     parser = argparse.ArgumentParser()
#     # we need the name of model, the name of dataset
#     parser.add_argument('--dataset', type=str, default='cifar10', help='name of dataset')
#     # parser.add_argument('--iot_model', type=str, default='mobilenetV2', help='name of the model on the iot')
#     parser.add_argument('--reducer', type=str, default='entrophy', help='name of the reducer')
#     parser.add_argument('--client', type=str, default='LTE', help='name of the network condition on the client side')
#     parser.add_argument('--server', type=str, default='LTE', help='name of the network condition on the server side')
#     parser.add_argument('--generator', type=str, default='None', help='name of the generator')
#     # parser.add_argument('--server_model', type=str, default='mobilenetV2', help='name of the model on the server, should be the same as it on the iot')
#     parser.add_argument('--device', type=str, default='home', help='run on which device, home, tintin, rpi, pico, jetson?')
#     parser.add_argument('--model', type=str, default='mobilenetV2', help='name of the model')
#     args = parser.parse_args()
#     main(args)

class custom_args:
    def __init__(self):
        self.dataset = 'cifar10'
        self.model = 'mobilenetV2'
        self.gated = True
        self.ranker = 'entropy'
        self.generator = False
        self.comment = 'exit at gate 1'

    def __str__(self):
        return 'dataset: '+self.dataset+', model: '+self.model+', gated: '+str(self.gated)+', ranker: '+self.ranker+', generator: '+str(self.generator)+', comment: '+self.comment

args = custom_args()
print(args)
main(args)
# Out:
# dataset: cifar10, model: mobilenetV2, gated: True, ranker: entropy, generator: False, comment: exit at gate 1
# Files already downloaded and verified
# Files already downloaded and verified
# The choosen gate is:  1 The confidence is:  0.5289991497993469 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5281652808189392 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5289924740791321 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5260090231895447 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5252110362052917 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5248402953147888 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5246038436889648 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5247176289558411 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5259746313095093 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5268127918243408 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5249622464179993 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5264410972595215 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525031328201294 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5248207449913025 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5245832800865173 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5261592864990234 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5261094570159912 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.52592933177948 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5261732935905457 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5244691371917725 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5258736610412598 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5270381569862366 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5271391272544861 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5250688195228577 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525216281414032 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525432288646698 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5263177156448364 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.528661847114563 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5263453722000122 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5254527926445007 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5254355669021606 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5264076590538025 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.527525782585144 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5252726078033447 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5250774025917053 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5255817770957947 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5245521664619446 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5273981094360352 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5246159434318542 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5270796418190002 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525809109210968 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5266671776771545 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5261108875274658 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5250729918479919 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5284733176231384 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5269784927368164 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5255029201507568 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5278233289718628 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.526144802570343 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525090754032135 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5249911546707153 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.52701735496521 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5284590125083923 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5258939862251282 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5250125527381897 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5240869522094727 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5265464186668396 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5270774960517883 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5244675278663635 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5273668766021729 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5262759327888489 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5258660912513733 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.524668276309967 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5259286165237427 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525965690612793 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5252612233161926 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5250809192657471 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5250259041786194 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5242359638214111 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5274062156677246 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5241768956184387 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5240966081619263 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5267505645751953 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5260609984397888 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5261256098747253 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.52780681848526 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5261028409004211 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5272778868675232 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5248556137084961 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525579571723938 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5285019278526306 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5233189463615417 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5253118276596069 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5271245241165161 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5248472690582275 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5262917876243591 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5262722373008728 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525585949420929 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5288425087928772 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5291672945022583 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5252927541732788 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5255707502365112 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.527304470539093 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.525238573551178 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5260453820228577 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5239936113357544 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5264163613319397 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5268263220787048 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5243862867355347 The size of channel is:  16
# The choosen gate is:  1 The confidence is:  0.5258581042289734 The size of channel is:  16
# Accuracy of the network on the 10000 test images: 92 %

# %%
# this is the total pipeline for the project
# This file is for trainning
# Run this on the server, or as we called offline. 

# with gated, no generator
from Dataloaders.dataloader_cifar10 import Dataloader_cifar10
import argparse
import torch
import os
import sys
import numpy as np
import time
from Models import mobilenetv2
from Utils import utils
from Models import gatedmodel
from Models import generator

def main(args):
    # initial using mobilenetV2, and cifar10
    # we need a if statement here to decide which model and dataset to use
    # random_seed = 2024

    # for training, it is for training the generator 
    # recall the graph, when we cut more features, the performance should be worse.
    
    # get the training loader, freeze the model. Where is the partitioning point? 

    # 1. get the train, test and val datasets, and labels.
    if args.dataset == 'cifar10':
        # return train, test, val, labels, these are all dataloaders
        _, test, classes = Dataloader_cifar10(train_batch=128, test_batch=100, seed=2024)
    elif args.dataset == 'cifar100':
        pass
    
    # 2. transfer the dataset to fit the model, for the training, client and server model are all on the server
    if args.model == 'mobilenetV2':
        client_model, server_model = mobilenetv2.stupid_model_splitter(weight_path='./Weights/cifar-10/MobileNetV2.pth')
    elif args.model == 'resnet':
        pass

    # 3. get the gating, gating here decides how many channels are transferred to the server
    # simple version: a binary tree, complex version: model
    # get a ranker to rank the channels, and get the top k channels
    ranker = utils.ranker_entropy # input: embs, percentage, output: s_emb, s_ind

    # 4. get the gated model, we have 3 models here
    gated_rates = [0.25, 0.5, 0.75]
    channel2ind = {8:0, 16:1, 24:2, 32:3}
    input_channel = 32
    gateds = []
    for i in range(3):
        gateds.append(gatedmodel.GatedRegression(
            input_size=int(input_channel*gated_rates[i]),
            weight=32,
            height=32,
            output_size=10)) #  input_size, weight, height, output_size=10

    # 5. get the generator
    generators = []
    for i in range(3):
        generators.append(generator.Generator(
            inputsize=int(input_channel*gated_rates[i]), 
            hiddensize=32, 
            outputsize=32)) # inputsize, hiddensize, outputsize
        
    # 6. get the server 
    # server_model = some_model_function()
    # server model is got above

    # pipline data -> dataloader -> client_model -> gating -> reducer -> generator -> server_model
    
    # cuda may not have enough space for putting all the models
    # client_model = client_model.cuda()
    # server_model = server_model.cuda()
    # for i in range(3):
    #     gateds[i] = gateds[i].cuda()
    #     generators[i] = generators[i].cuda()

    # set them to eval
    client_model.eval()
    server_model.eval()
    for i in range(3):
        gateds[i].eval()
        generators[i].eval()

    globbal_threshold = 0.8 # set a small value first

    # load the test data set the test
    with torch.no_grad():
        correct = 0
        total = 0
        client_model = client_model.cuda()
        server_model = server_model.cuda()
        for data in test:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            # first, run the client model on the iot
            out = client_model(images)
            # second, run the ranker
            exit_flag = args.gated
            counter = 0
            while exit_flag:
                # get the emb and ind from the ranker
                out = out.cpu()
                s_emb, s_ind = ranker(out, gated_rates[counter])
                s_emb = s_emb.cuda()
                # give it to the gated model
                cur_gated = gateds[counter]
                # load the weights
                cur_gated.load_state_dict(torch.load('./Weights/cifar-10/GatedRegression_'+str(counter)+'.pth'))
                cur_gated = cur_gated.cuda()
                g_emb = cur_gated(s_emb) # b, n
                # get the argmax
                g_conf = torch.max(g_emb, dim=1).values # b
                # use the sigmoid to get the confidence
                g_conf = torch.nn.functional.sigmoid(g_conf) # b
                # if in a batch, get the average
                g_conf = torch.mean(g_conf)
                # print('The confidence is: ', g_conf.item())
                if counter == 0:
                    exit_flag = not exit_flag
                    break
                if g_conf > globbal_threshold:
                    exit_flag = not exit_flag
                else:
                    counter += 1

            # check the exit flag and send
            if exit_flag != args.gated:
                print('The choosen gate is: ', counter, 'The confidence is: ', g_conf.item(), 'The size of channel is: ', s_emb.size(1))
                out = s_emb

            # a sender here, but on server, we don't have it.
            
            # a receiver here, but on server, we don't have it.
            # get the generator
            rec_size = out.size(1)
            if exit_flag != args.gated:
                rec_ind = s_ind
            rec_size2ind = channel2ind[rec_size]
            # if we don't get all features, we need to use the generator

            if args.generator:
                if rec_size2ind != 3:
                    cur_gen = generators[rec_size2ind]
                    # load weights
                    cur_gen.load_state_dict(torch.load('./Weights/cifar-10/generator_'+str(rec_size2ind)+'.pth'))
                    cur_gen = cur_gen.cuda()
                    out = cur_gen(out)

            # skip the generator, create a tensor with all zeros
            else:
                if exit_flag != args.gated:
                    n_out = torch.zeros(out.size(0), 32, 32, 32).cuda()
                    n_out[:, rec_ind, :, :] = out
                    out = n_out

            # run the server model
            out = server_model(out)
            _, predicted = torch.max(out.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))

# if __name__ == '__main__':
#     print('enter')
#     parser = argparse.ArgumentParser()
#     # we need the name of model, the name of dataset
#     parser.add_argument('--dataset', type=str, default='cifar10', help='name of dataset')
#     # parser.add_argument('--iot_model', type=str, default='mobilenetV2', help='name of the model on the iot')
#     parser.add_argument('--reducer', type=str, default='entrophy', help='name of the reducer')
#     parser.add_argument('--client', type=str, default='LTE', help='name of the network condition on the client side')
#     parser.add_argument('--server', type=str, default='LTE', help='name of the network condition on the server side')
#     parser.add_argument('--generator', type=str, default='None', help='name of the generator')
#     # parser.add_argument('--server_model', type=str, default='mobilenetV2', help='name of the model on the server, should be the same as it on the iot')
#     parser.add_argument('--device', type=str, default='home', help='run on which device, home, tintin, rpi, pico, jetson?')
#     parser.add_argument('--model', type=str, default='mobilenetV2', help='name of the model')
#     args = parser.parse_args()
#     main(args)

class custom_args:
    def __init__(self):
        self.dataset = 'cifar10'
        self.model = 'mobilenetV2'
        self.gated = True
        self.ranker = 'entropy'
        self.generator = False
        self.comment = 'exit at gate 0'

    def __str__(self):
        return 'dataset: '+self.dataset+', model: '+self.model+', gated: '+str(self.gated)+', ranker: '+self.ranker+', generator: '+str(self.generator)+', comment: '+self.comment

args = custom_args()
print(args)
main(args)
# Out:
# dataset: cifar10, model: mobilenetV2, gated: True, ranker: entropy, generator: False, comment: exit at gate 0
# Files already downloaded and verified
# Files already downloaded and verified
# The choosen gate is:  0 The confidence is:  0.5168089270591736 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161352157592773 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5168091654777527 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5164685845375061 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5157368183135986 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5154076814651489 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163465142250061 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5157496333122253 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5164365768432617 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5166762471199036 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5165131092071533 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5167126059532166 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5167576670646667 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.517125129699707 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163633823394775 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5160406231880188 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5160723924636841 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5168569087982178 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5162472128868103 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5169522166252136 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5164923071861267 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.516463041305542 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161190032958984 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.515986442565918 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5162471532821655 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5154345035552979 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5155271291732788 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.516184389591217 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5164639949798584 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5169898271560669 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5167553424835205 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161944627761841 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163817405700684 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161073803901672 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.515794038772583 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5160513520240784 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5167967081069946 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5164154171943665 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5162898302078247 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161844491958618 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5168585181236267 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5164912939071655 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.516336977481842 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5166959762573242 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5170579552650452 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163618922233582 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5157530903816223 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5171453952789307 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161389112472534 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5159121751785278 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163440108299255 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.516255795955658 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161259174346924 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.517071545124054 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5167104005813599 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5160457491874695 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.51656574010849 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.51646888256073 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.516349196434021 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5167478919029236 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5160191059112549 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161833763122559 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5157601237297058 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5158578157424927 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5155773758888245 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5171032547950745 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5157927870750427 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5167110562324524 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5164558291435242 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5160751342773438 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161113142967224 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5166157484054565 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163779854774475 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5165132284164429 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5171903967857361 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5171880125999451 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5160483717918396 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163145065307617 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5168694853782654 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5161784887313843 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5166643261909485 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5171595215797424 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5150583386421204 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5157114267349243 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5167725086212158 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5174809098243713 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5155881643295288 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5171048045158386 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5166884064674377 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163586735725403 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5163263082504272 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5155735015869141 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5168127417564392 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5154456496238708 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5173866748809814 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5165847539901733 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5166252851486206 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5169580578804016 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.516812264919281 The size of channel is:  8
# The choosen gate is:  0 The confidence is:  0.5165206789970398 The size of channel is:  8
# Accuracy of the network on the 10000 test images: 14 %
