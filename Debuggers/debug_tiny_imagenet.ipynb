# %%
p = 'n01443537_0.JPEG'	
box = [0,10,63,58]
# 
from PIL import Image
import matplotlib.pyplot as plt
pic = Image.open('../data/tiny-imagenet-200/train/n01443537/images/'+p)
pic = pic.crop(box)
plt.imshow(pic)

# %%
a = '122351346412641'
a[:-3]
# Out:
# '122351346412'
