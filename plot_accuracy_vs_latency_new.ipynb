# %% [markdown]
# # plot the performance of ResNet on ccpd

# %% [markdown]
# # New strategy to measure latency

# %%
# GF = gate frequency
import numpy as np
GF_resnet_1 = [
 np.array('1 0 0 0 0 0 0 0' .split()),
 np.array('0.71 0.29 0 0 0 0 0 0 '.split()),
 np.array('0 1 0 0 0 0 0 0'.split()),
 np.array('0 0.056 0.944 0 0 0 0 0 '.split()),
 np.array('0 0.018 0.97 0.012 0 0 0 0 '.split()),
 np.array('0 0.007 0.88 0.113 0 0 0 0 '.split()),
 np.array('0 0.002 0.313 0.685 0 0 0 0 '.split()),
 np.array('0 0 0.049 0.946 0.005 0 0 0 '.split()),
 np.array('0 0 0.008 0.822 0.152 0.011 0 0.007'.split()),
 np.array('0 0 0 0.186 0.399 0.162 0.058 0.195'.split()),
 np.array('0 0 0 0.036 0.118 0.141 0.087 0.618'.split()),
 np.array('0 0 0 0 0 0 0 1'.split()),
]
GF_resnet_1 = np.array(GF_resnet_1)

GF_resnet_2 = [
 np.array('1 0 0 0 0 0 0 0 0' .split()),
 np.array('0.325 0.675 0  0  0  0  0  0  0 '.split()),
 np.array('0.173 0.212 0.605 0.01  0  0  0  0  0 '.split()),
 np.array('0.095 0.058 0.587 0.26  0  0  0  0  0 '.split()),
 np.array('0.049 0.028 0.2 0.716 0.004 0.003 0  0  0 '.split()),
 np.array('0.026 0.012 0.051 0.856 0.038 0.015 0.001 0  0.001'.split()),
 np.array('0.015 0.005 0.018 0.732 0.143 0.07  0.013 0.001 0.003'.split()),
 np.array('0.005 0  0.007 0.418 0.308 0.144 0.068 0.033 0.017'.split()),
 np.array('0.001 0  0.001 0.132 0.309 0.219 0.113 0.127 0.098'.split()),
 np.array('0  0  0  0.028 0.089 0.133 0.137 0.189 0.424'.split()),
 np.array('0  0  0  0.01  0.032 0.056 0.04  0.096 0.766'.split()),
 np.array('0 0 0 0 0 0 0 0 1'.split()),
]
for i in range(len(GF_resnet_2)):
    print(GF_resnet_2[i].shape)
GF_resnet_2 = np.array(GF_resnet_2)

GF_mobile_1 = [
 np.array('1 0 0 0 0 0 0' .split()),
 np.array('1 0 0 0 0 0 0' .split()),
 np.array('1 0 0 0 0 0 0' .split()),
 np.array('1 0 0 0 0 0 0' .split()),
 np.array('1 0 0 0 0 0 0' .split()),
 np.array('0.403 0.585 0.012 0  0  0  0 '.split()),
 np.array('0  0.304 0.691 0.005 0  0  0 '.split()),
 np.array('0  0.036 0.943 0.021 0  0  0 '.split()),
 np.array('0  0.002 0.939 0.059 0  0  0 '.split()),
 np.array('0  0  0.08  0.898 0.022 0  0 '.split()),
 np.array('0  0  0  0.513 0.244 0.16  0.083'.split()),
 np.array('0 0 0 0 0 0 1'.split()),
]
for i in range(len(GF_mobile_1)):
    print(GF_mobile_1[i].shape)
GF_mobile_1 = np.array(GF_mobile_1)

GF_mobile_2 = [
 np.array('1 0 0 0 0 0 0 0' .split()),
 np.array('0.954 0.046 0  0  0  0  0  0 '.split()),
 np.array('0.842 0.148 0.01  0  0  0  0  0 '.split()),
 np.array('0  0.965 0.035 0  0  0  0  0 '.split()),
 np.array('0  0.898 0.102 0  0  0  0  0 '.split()),
 np.array('0  0.114 0.88  0.006 0  0  0  0 '.split()),
 np.array('0  0.001 0.968 0.03  0.001 0  0  0 '.split()),
 np.array('0  0  0.502 0.473 0.025 0  0  0 '.split()),
 np.array('0  0  0.033 0.466 0.489 0.012 0  0 '.split()),
 np.array('0  0  0.001 0.062 0.599 0.245 0.046 0.047'.split()),
 np.array('0  0  0  0.014 0.086 0.15  0.093 0.657'.split()),
 np.array('0 0 0 0 0 0 0 1'.split()),
]
GF_mobile_2 = np.array(GF_mobile_2)
# Out:
# (9,)
# (9,)
# (9,)
# (9,)
# (9,)
# (9,)
# (9,)
# (9,)
# (9,)
# (9,)
# (9,)
# (9,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)

# %%
GA_mobilenet_1 = "0.487	0.487	0.487	0.487	0.487	0.556	0.764	0.824	0.832	0.875	0.878	0.909"
GA_mobilenet_1 = [float(x) for x in GA_mobilenet_1.split()]

GA_mobilenet_2 = "0.179	0.188	0.216	0.434	0.45	0.646	0.673	0.702	0.778	0.827	0.855	0.874"
GA_mobilenet_2 = [float(x) for x in GA_mobilenet_2.split()]

GA_resnet_1 = "0.09	0.136	0.221	0.607	0.627	0.66	0.784	0.829	0.839	0.86	0.896	0.901"
GA_resnet_1 = [float(x) for x in GA_resnet_1.split()]

GA_resnet_2 = "0.121	0.173	0.307	0.419	0.572	0.632	0.666	0.725	0.787	0.845	0.874	0.884"
GA_resnet_2 = [float(x) for x in GA_resnet_2.split()]

# %%
JA_resnet_imagenet = '0.91, 0.93791, 0.9509379099999999, 0.94995093791, 0.94994995093791, 0.953949949950938, 0.951953949949951, 0.9529519539499499, 0.9549529519539499, 0.958954952951954'.split(',')
JA_resnet_imagenet = [float(JA_resnet_imagenet[i]) for i in range(10)]

JA_mobile_imagenet = '0.893, 0.935893, 0.9449358929999999, 0.948944935893, 0.944948944935893, 0.944944948944936, 0.9539449449489449, 0.9529539449449489, 0.951952953944945, 0.954951952953945'.split(',')
JA_mobile_imagenet = [float(JA_mobile_imagenet[i]) for i in range(10)]

# %%
GTL_mobile_1= {100:None, 250:None}
GTL_resnet_temp = '415.07	415.07	415.07	415.07	415.07	618.74	1129.93	1254.27	1300.35	2099.68	3638.74	10468.54'.split()
GTL_resnet_temp = [float(x) for x in GTL_resnet_temp]
GTL_mobile_1[100] = GTL_resnet_temp
GTL_resnet_temp = '227.07	227.07	227.07	227.07	227.07	303.7	495.66	559.48	581.67	894.94	1507.51	4224.36'.split()
GTL_resnet_temp = [float(x) for x in GTL_resnet_temp]
GTL_mobile_1[250] = GTL_resnet_temp

GTL_mobile_2= {100:None, 250:None}
GTL_resnet_temp = '204.97	209.69	219.93	287.71	297.34	410.99	430.23	534.32	862.25	1520.79	4449.79	5747'.split()
GTL_resnet_temp = [float(x) for x in GTL_resnet_temp]
GTL_mobile_2[100] = GTL_resnet_temp
GTL_resnet_temp = '138.36	141.47	145.45	172.77	176.61	222.24	229.92	271.49	394.26	670.58	1825.31	2339.08'.split()
GTL_resnet_temp = [float(x) for x in GTL_resnet_temp]
GTL_mobile_2[250] = GTL_resnet_temp


GTL_resnet_1= {100:None, 250:None}
GTL_mobile_temp = '200.99	224.47	282.9	422.82	431.03	467.53	611.19	679.97	794.49	2084.27	4158.45	5692.49'.split()
GTL_mobile_temp = [float(x) for x in GTL_mobile_temp]
GTL_resnet_1[100] = GTL_mobile_temp
GTL_mobile_temp = '137.36	147.59	170.87	226.94	230.14	241.44	302	329.67	372.87	887.32	1708.68	2316.74'.split()
GTL_mobile_temp = [float(x) for x in GTL_mobile_temp]
GTL_resnet_1[250] = GTL_mobile_temp

GTL_resnet_2= {100:None, 250:None}
GTL_mobile_temp = '145.3	160.7	189.54	220.34	261.72	290.66	338.1	505.83	925.27	1923.74	2742.57	3173.87'.split()
GTL_mobile_temp = [float(x) for x in GTL_mobile_temp]
GTL_resnet_2[100] = GTL_mobile_temp
GTL_mobile_temp = '115.69	122.08	166.49	145.92	162.45	173.13	192.11	259.3	428.01	833.96	1148.87	1306.16'.split()
GTL_mobile_temp = [float(x) for x in GTL_mobile_temp]
GTL_resnet_2[250] = GTL_mobile_temp

# %%
JL_imagenet = {100:None, 250:None, }
JL_imagenet_temp = '368.36   667.85  769.91  883.07  1002.12 1135.86 1343.37 1684.4  2352.09 5244.91'.split()
JL_imagenet_temp = [float(x) for x in JL_imagenet_temp]
JL_imagenet[100] = JL_imagenet_temp
JL_imagenet_temp = '170.82   341.95  395.49  440.38  486.64  540.52  626.57  754.96  1548.83 2135.51'.split()
JL_imagenet_temp = [float(x) for x in JL_imagenet_temp]
JL_imagenet[250] = JL_imagenet_temp
JL_imagenet_temp = '106.47   242.22  273.72  297.4   315.16  342.12  385.28  448.8   587.73  1098.7'.split()

# %%
GCL_mobile_1 = '17.12441444	18.91052723	25.49779415	28.37395668	47.68610001	71.44343853	191.7401552'.split()
GCL_mobile_1 = [float(x) for x in GCL_mobile_1]
GCL_mobile_2 = '21.73185349	21.39604092	23.03099632	24.10840988	25.62522888	31.90600872	42.46425629	89.54417706'.split()
GCL_mobile_2 = [float(x) for x in GCL_mobile_2]
GCL_resnet_1 = '28.99241447	27.85027027	28.3973217	29.40559387	33.73003006	38.27667236	44.30389404	74.91374016'.split()
GCL_resnet_1 = [float(x) for x in GCL_resnet_1]
GCL_resnet_2 = '31.67247772	31.99231625	32.01544285	32.81927109	35.5553627	36.50546074	38.59448433	43.15543175	59.50713158'.split()
GCL_resnet_2 = [float(x) for x in GCL_resnet_2]

# %%
OCL_mobile_imagenet = 324.00
OCL_resnet_imagenet = 459.13

# %%
# convert them to arracy
import numpy as np
# GF_resnet_imagenet = {k:np.array(v) for k,v in GF_resnet_imagenet.items()}
# GF_mobile_imagenet = {k:np.array(v) for k,v in GF_mobile_imagenet.items()}
# GF_resnet_cifar = {k:np.array(v) for k,v in GF_resnet_cifar.items()}
# GF_mobile_cifar = {k:np.array(v) for k,v in GF_mobile_cifar.items()}
# GF_resnet_ccpd = {k:np.array(v) for k,v in GF_resnet_ccpd.items()}
# GF_mobile_ccpd = {k:np.array(v) for k,v in GF_mobile_ccpd.items()}
GTL_mobile_1 = {k:np.array(v) for k,v in GTL_mobile_1.items()}
GTL_mobile_2 = {k:np.array(v) for k,v in GTL_mobile_2.items()}
GTL_resnet_1 = {k:np.array(v) for k,v in GTL_resnet_1.items()}
GTL_resnet_2 = {k:np.array(v) for k,v in GTL_resnet_2.items()}
JL_imagenet = {k:np.array(v) for k,v in JL_imagenet.items()}
GCL_mobile_1 = np.array(GCL_mobile_1)
GCL_mobile_2 = np.array(GCL_mobile_2)
GCL_resnet_1 = np.array(GCL_resnet_1)
GCL_resnet_2 = np.array(GCL_resnet_2)
GA_mobilenet_1 = np.array(GA_mobilenet_1)
GA_mobilenet_2 = np.array(GA_mobilenet_2)
GA_resnet_1 = np.array(GA_resnet_1)
GA_resnet_2 = np.array(GA_resnet_2)
JA_resnet_imagenet = np.array(JA_resnet_imagenet)
JA_mobile_imagenet = np.array(JA_mobile_imagenet)
OCL_mobile_imagenet = np.array(OCL_mobile_imagenet)
OCL_resnet_imagenet = np.array(OCL_resnet_imagenet)

# %%
network_conditions = [100, 250]
models = ['mobile', 'resnet']

# %%
# plot the accuracy vs latency for different network conditions
import matplotlib.pyplot as plt
import numpy as np

for ind, nc in enumerate(network_conditions):

    M_1 = np.dot(GF_mobile_1.astype('float'), GCL_mobile_1)  + GTL_mobile_1[nc]
    M_2 = np.dot(GF_mobile_2.astype('float'), GCL_mobile_2)  + GTL_mobile_2[nc]
    R_1 = np.dot(GF_resnet_1.astype('float'), GCL_resnet_1)  + GTL_resnet_1[nc]
    R_2 = np.dot(GF_resnet_2.astype('float'), GCL_resnet_2)  + GTL_resnet_2[nc]
    J = JL_imagenet[nc] * 3

    fig, ax = plt.subplots()
    ax.plot(M_1, GA_mobilenet_1, label='MobileNet-1', marker='o')
    ax.plot(M_2, GA_mobilenet_2, label='MobileNet-2', marker='o')
    # ax.plot(R_1, GA_resnet_1, label='ResNet-1', marker='o')
    # ax.plot(R_2, GA_resnet_2, label='ResNet-2', marker='o')
    # ax.plot(J, JA_resnet_imagenet, label='ResNet-ImageNet', marker='o')
    # ax.plot(J, JA_mobile_imagenet, label='MobileNet-ImageNet', marker='o')
    ax.set_xlabel('Latency (ms)')
    ax.set_ylabel('Accuracy')
    ax.set_title('Accuracy vs Latency for different models')
    ax.legend(['mobile_1', 'mobile_2', 'resnet_1', 'resnet_2', 'resnet_JPEG', 'mobile_JPEG'])
    plt.show()
